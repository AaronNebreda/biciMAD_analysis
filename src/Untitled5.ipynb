# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.5.2-cp310-cp310-win_amd64.whl (10.4 MB)
#      ---------------------------------------- 10.4/10.4 MB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Collecting numpy>=1.21.0
#   Downloading numpy-1.23.5-cp310-cp310-win_amd64.whl (14.6 MB)
#      ---------------------------------------- 14.6/14.6 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.23.5 pandas-1.5.2 pytz-2022.6
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\aaron\anaconda3\envs\maps\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from geopandas) (1.5.2)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp310-cp310-win_amd64.whl (21.7 MB)
#      -------------------------------------- 21.7/21.7 MB 723.0 kB/s eta 0:00:00
# Collecting shapely>=1.7
#   Downloading shapely-2.0.0-cp310-cp310-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 2.2 MB/s eta 0:00:00
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp310-cp310-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.7 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Collecting cligj>=0.5
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting click-plugins>=1.0
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting attrs>=17
#   Using cached attrs-22.1.0-py2.py3-none-any.whl (58 kB)
# Collecting munch
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting click>=4.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: setuptools in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas) (65.5.0)
# Requirement already satisfied: certifi in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas) (2022.9.24)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from pandas>=1.0.0->geopandas) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from pandas>=1.0.0->geopandas) (2022.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from click>=4.0->fiona>=1.8->geopandas) (0.4.5)
# Installing collected packages: shapely, pyproj, munch, click, attrs, cligj, click-plugins, fiona, geopandas
# Successfully installed attrs-22.1.0 click-8.1.3 click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1 shapely-2.0.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pyproj.exe is installed in 'C:\Users\aaron\anaconda3\envs\maps\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fio.exe is installed in 'C:\Users\aaron\anaconda3\envs\maps\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# %pip install keplergl
# Out:
# Collecting keplergl
#   Using cached keplergl-0.3.2.tar.gz (9.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas>=0.23.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from keplergl) (1.5.2)
# Collecting ipywidgets<8,>=7.0.0
#   Using cached ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
# Requirement already satisfied: geopandas>=0.5.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from keplergl) (0.12.2)
# Requirement already satisfied: Shapely>=1.6.4.post2 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from keplergl) (2.0.0)
# Collecting traittypes>=0.2.1
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from geopandas>=0.5.0->keplergl) (3.4.1)
# Requirement already satisfied: fiona>=1.8 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from geopandas>=0.5.0->keplergl) (1.8.22)
# Requirement already satisfied: packaging in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from geopandas>=0.5.0->keplergl) (21.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (6.15.2)
# Collecting ipython-genutils~=0.2.0
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Using cached jupyterlab_widgets-1.1.1-py3-none-any.whl (245 kB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (5.1.1)
# Collecting widgetsnbextension~=3.6.0
#   Using cached widgetsnbextension-3.6.1-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipywidgets<8,>=7.0.0->keplergl) (8.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from pandas>=0.23.0->keplergl) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from pandas>=0.23.0->keplergl) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from pandas>=0.23.0->keplergl) (2022.6)
# Requirement already satisfied: six>=1.7 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (65.5.0)
# Requirement already satisfied: attrs>=17 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (22.1.0)
# Requirement already satisfied: munch in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (2.5.0)
# Requirement already satisfied: click>=4.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (8.1.3)
# Requirement already satisfied: certifi in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from fiona>=1.8->geopandas>=0.5.0->keplergl) (2022.9.24)
# Requirement already satisfied: pyzmq>=17 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (23.2.0)
# Requirement already satisfied: psutil in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (7.4.7)
# Requirement already satisfied: jedi>=0.16 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (3.0.20)
# Requirement already satisfied: decorator in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.11.2)
# Requirement already satisfied: colorama in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.4.5)
# Requirement already satisfied: pickleshare in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.7.5)
# Requirement already satisfied: backcall in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.0)
# Collecting notebook>=4.4.1
#   Using cached notebook-6.5.2-py3-none-any.whl (439 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from packaging->geopandas>=0.5.0->keplergl) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (4.11.2)
# Requirement already satisfied: entrypoints in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (0.4)
# Collecting jinja2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting nbformat
#   Using cached nbformat-5.7.0-py3-none-any.whl (77 kB)
# Collecting nbconvert>=5
#   Using cached nbconvert-7.2.6-py3-none-any.whl (273 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting nbclassic>=0.4.7
#   Using cached nbclassic-0.4.8-py3-none-any.whl (9.8 MB)
# Collecting prometheus-client
#   Using cached prometheus_client-0.15.0-py3-none-any.whl (60 kB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: wcwidth in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (2.0.5)
# Requirement already satisfied: executing in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8,>=7.0.0->keplergl) (0.8.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7.0.0->keplergl) (305.1)
# Collecting jupyter-server>=1.8
#   Using cached jupyter_server-2.0.1-py3-none-any.whl (360 kB)
# Collecting notebook-shim>=0.1.0
#   Using cached notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting mistune<3,>=2.0.3
#   Using cached mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting markupsafe>=2.0
#   Using cached MarkupSafe-2.1.1-cp310-cp310-win_amd64.whl (17 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.7.2-py3-none-any.whl (71 kB)
# Collecting tinycss2
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting bleach
#   Using cached bleach-5.0.1-py3-none-any.whl (160 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting jsonschema>=2.6
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting fastjsonschema
#   Using cached fastjsonschema-2.16.2-py3-none-any.whl (22 kB)
# Collecting pywinpty>=1.1.0
#   Using cached pywinpty-2.0.9-cp310-none-win_amd64.whl (1.4 MB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Using cached pyrsistent-0.19.2-cp310-cp310-win_amd64.whl (62 kB)
# Collecting jupyter-core>=4.9.2
#   Using cached jupyter_core-5.1.0-py3-none-any.whl (92 kB)
# Collecting jupyter-server-terminals
#   Using cached jupyter_server_terminals-0.4.2-py3-none-any.whl (13 kB)
# Collecting anyio<4,>=3.1.0
#   Using cached anyio-3.6.2-py3-none-any.whl (80 kB)
# Collecting jupyter-events>=0.4.0
#   Using cached jupyter_events-0.5.0-py3-none-any.whl (17 kB)
# Collecting websocket-client
#   Using cached websocket_client-1.4.2-py3-none-any.whl (55 kB)
# Collecting pyzmq>=17
#   Using cached pyzmq-24.0.1-cp310-cp310-win_amd64.whl (992 kB)
# Collecting traitlets>=4.3.1
#   Using cached traitlets-5.7.1-py3-none-any.whl (109 kB)
# Collecting platformdirs>=2.5
#   Using cached platformdirs-2.6.0-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting idna>=2.8
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting python-json-logger
#   Using cached python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# Collecting pyyaml
#   Using cached PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting webcolors>=1.11
#   Using cached webcolors-1.12-py3-none-any.whl (9.9 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>0.1.0
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting uri-template
#   Using cached uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Building wheels for collected packages: keplergl
#   Building wheel for keplergl (pyproject.toml): started
#   Building wheel for keplergl (pyproject.toml): finished with status 'done'
#   Created wheel for keplergl: filename=keplergl-0.3.2-py2.py3-none-any.whl size=17922326 sha256=0796ee34940e9af2400e642c3a4cbe42197c8b90c8814f61ecf6d24f63cb1689
#   Stored in directory: c:\users\aaron\appdata\local\pip\cache\wheels\9b\51\6c\2b7e19f59d53f18a26ee41f8d26e6975533effac6bb4ea449d
# Successfully built keplergl
# Installing collected packages: webencodings, Send2Trash, mistune, ipython-genutils, fastjsonschema, websocket-client, webcolors, uri-template, traitlets, tinycss2, soupsieve, sniffio, rfc3986-validator, rfc3339-validator, pyzmq, pyyaml, pywinpty, python-json-logger, pyrsistent, pycparser, prometheus-client, platformdirs, pandocfilters, markupsafe, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, idna, fqdn, defusedxml, bleach, traittypes, terminado, jupyter-core, jsonschema, jinja2, cffi, beautifulsoup4, arrow, anyio, nbformat, jupyter-server-terminals, isoduration, argon2-cffi-bindings, nbclient, argon2-cffi, nbconvert, jupyter-events, jupyter-server, notebook-shim, nbclassic, notebook, widgetsnbextension, ipywidgets, keplergl
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.1.1
#     Uninstalling traitlets-5.1.1:
#       Successfully uninstalled traitlets-5.1.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.0
#     Uninstalling pyzmq-23.2.0:
#       Successfully uninstalled pyzmq-23.2.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script send2trash.exe is installed in 'C:\Users\aaron\anaconda3\envs\maps\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wsdump.exe is installed in 'C:\Users\aaron\anaconda3\envs\maps\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\aaron\\anaconda3\\envs\\maps\\Lib\\site-packages\\~mq\\backend\\cython\\context.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
import geopandas as gpd

from keplergl import KeplerGl

import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import geopandas as gpd
# ----> 3 from keplergl import KeplerGl
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'keplergl'

# %%
mapa_k=KeplerGl(height=600, width=800)  # inicializas el mapa

mapa_k.add_data(mex.copy(), 'Mexico')  # se añaden datos con un nombre

mapa_k.save_to_html(file_name='mapa_kepler.html')  # se guarda

mapa_k # se representa

# %%
# %pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ------------------------------------ 102.3/102.3 kB 535.1 kB/s eta 0:00:00
# Collecting requests
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Requirement already satisfied: numpy in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from folium) (1.23.5)
# Collecting jinja2>=2.9
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting branca>=0.6.0
#   Using cached branca-0.6.0-py3-none-any.whl (24 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.1-cp310-cp310-win_amd64.whl (17 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aaron\anaconda3\envs\maps\lib\site-packages (from requests->folium) (2022.9.24)
# Installing collected packages: urllib3, MarkupSafe, idna, charset-normalizer, requests, jinja2, branca, folium
# Successfully installed MarkupSafe-2.1.1 branca-0.6.0 charset-normalizer-2.1.1 folium-0.14.0 idna-3.4 jinja2-3.1.2 requests-2.28.1 urllib3-1.26.13
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\aaron\anaconda3\envs\maps\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
